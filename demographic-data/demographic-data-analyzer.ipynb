# %%
import pandas as pd

# %%
df = pd.read_csv('adult.data.csv')

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
race=list(set(df.race))
cn=[sum(df['race']==x) for x in race]
race_count= pd.Series(cn)

# %%
race_count
# Out:
# 0      311
# 1      271
# 2     1039
# 3     3124
# 4    27816
# dtype: int64

# %%
set(df.race)
# Out:
# {'Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'}

# %%
average_age_men = sum(df.age)/len(df)
average_age_men
# Out:
# 38.58164675532078

# %%
percentage_bachelors = 100*len(df[df.education == 'Bachelors'])/len(df)
percentage_bachelors
# Out:
# 16.446055096587944

# %%
higher_education = df[df.education.isin(['Bachelors', 'Masters', 'Doctorate'])]
higher_education
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
lower_education = df[~df.education.isin(he)]
lower_education
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
higher_education_rich = len(higher_education[higher_education.salary == '>50K'])*100/len(higher_education)
higher_education_rich
# Out:
# 46.535843011613935

# %%
lower_education_rich = len(lower_education[lower_education.salary == '>50K'])*100/len(lower_education)
lower_education_rich
# Out:
# 17.3713601914639

# %%
min_work_hours = min(df['hours-per-week'])

# %%
sum(df[df['hours-per-week']==min_work_hours].salary == '>50K')*100/sum(df['hours-per-week']==min_work_hours)
# Out:
# 10.0

# %%
country = set(df['native-country'])

# %%
highest_earning_country_percentage=0
highest_earning_country=''
for x in country:
    per = sum(df[df['native-country'] == x].salary == '>50K')*100/sum(df['native-country'] == x)
    if per>highest_earning_country_percentage:
        highest_earning_country_percentage=per
        highest_earning_country=x
print(highest_earning_country_percentage)
print(highest_earning_country)
# Out:
# 41.86046511627907
# Iran

# %%
sum(df[df['native-country'] == 'United-States'].salary == '>50K')
# Out:
# 7171

# %%
sum(df['native-country'] == 'United-States')
# Out:
# 29170

# %%
india=df[df['native-country']=='India']
india=india[india['salary'] == '>50K']
list(india.occupation.mode())[0]
# Out:
# 'Prof-specialty'
